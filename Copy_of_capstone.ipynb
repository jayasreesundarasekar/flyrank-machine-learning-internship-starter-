# %% [markdown]
# <a href="https://colab.research.google.com/github/jayasreesundarasekar/flyrank-machine-learning-internship-starter-/blob/main/Copy_of_capstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Capstone — mirrors your deployed research paper
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jayasreesundarasekar/flyrank-machine-learning-internship-starter-/blob/main/work/notebooks/capstone.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Question
#
# *The research question and the decision it supports.*

# %%
# Define the research question for the capstone.
# Keep the question specific to the lane and avoid causal claims.

research_question = (
    "Can historical search signals be used to prioritize "
    "content opportunities for human review?"
)

print("Research question:")
print(research_question)

# %% [markdown]
# ## 2. Data
#
# *Which release, which tables, date windows, what you excluded and why. Public-safe.*

# %%
# Summarize the dataset used by the analysis.
# Replace these values with the actual values from your warehouse queries.

print("Dataset release: FlyRank Internship Dataset")
print("Development window: 2026-03")
print("Final/test window: kept sealed where applicable")

print("Rows used:", len(df))
print("Date range:", df["date"].min(), "to", df["date"].max())

# Confirm that the target is not being used as an input feature.
assert TARGET not in FEATURES

print("Excluded label-derived features: confirmed")
print("Future-window features: excluded")

# %% [markdown]
# ## 3. Methodology
#
# *Assumptions, features, label definition, baseline, validation design, leakage checks.*

# %%
# Show the final features used by the model.

print("Final model features:")
for feature in FEATURES:
    print("-", feature)

print("\nTarget:", TARGET)

# Baseline and validation design.
print("\nBaseline: Week-4 rule-based action score")
print("Model: Week-5 validated model")
print("Validation: time-aware split")
print("Leakage check: completed")

# %% [markdown]
# ## 4. Results (vs baseline)
#
# *Model vs baseline on the same split. The honest table.*

# %%
# Compare the Week-4 baseline and Week-5 model
# using exactly the same evaluation metric and validation data.

results = pd.DataFrame({
    "method": [
        "Week-4 baseline",
        "Week-5 model"
    ],
    "metric": [
        "F1",
        "F1"
    ],
    "score": [
        WEEK4_BASELINE_SCORE,
        WEEK5_MODEL_SCORE
    ]
})

display(results)

# Difference between model and baseline.
difference = WEEK5_MODEL_SCORE - WEEK4_BASELINE_SCORE

print("Model - baseline:", difference)

if difference > 0:
    print("Observed result: model measured higher performance.")
elif difference < 0:
    print("Observed result: baseline measured higher performance.")
else:
    print("Observed result: model and baseline measured the same performance.")

# %% [markdown]
# ## 5. Limitations
#
# *What this work cannot claim.*

# %%
# Summarize limitations as observations rather than universal claims.

limitations = [
    "The analysis uses historical warehouse observations and may not generalize to future distributions.",
    "The model identifies directional associations rather than causal effects.",
    "The ranked recommendations require human review before action.",
    "Performance depends on the available signals and their data quality.",
    "The evaluation does not establish that recommended actions will produce business outcomes."
]

for i, limitation in enumerate(limitations, 1):
    print(f"{i}. {limitation}")

# %% [markdown]
# ## 6. Ranked recommendations
#
# *The action playbook output — the paper's recommendations section.*

# %%
# Load the ranked queue generated by Week 7.

queue_path = "work/outputs/w07_ranked_action_queue.csv"

recommendations = pd.read_csv(queue_path)

# Display the highest-ranked recommendations.
top_recommendations = recommendations.head(20)

display(top_recommendations)

print("Recommendations shown:", len(top_recommendations))

# %% [markdown]
# ## 7. Artifacts the paper embeds
#
# *Generate/collect the charts and tables your deployed page will show.*

# %%
from pathlib import Path

# Check that the main paper artifacts exist.

artifacts = [
    "work/outputs/w07_ranked_action_queue.csv",
    "work/figures/model_vs_baseline.png"
]

for artifact in artifacts:
    exists = Path(artifact).exists()
    print(("✓" if exists else "✗"), artifact)

    if not exists:
        print("   Missing artifact — generate it before deployment.")

# Basic public-safety checks before deployment.

forbidden_terms = [
    "client_name",
    "private_query",
    "internal_url"
]

text_to_check = " ".join(
    str(value)
    for value in df.columns
)

for term in forbidden_terms:
    print(term, "found:", term.lower() in text_to_check.lower())

print("\nFinal reminder:")
print("- Use public-safe claims.")
print("- Do not expose client names or private queries.")
print("- Do not expose credentials or tokens.")
print("- Describe results as observed/measured/directional.")

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
# - [ ] My deployed paper has **all 9 sections** — including the **Abstract** at the top and **Acknowledgments & data credit** (the https://flyrank.ai link) at the bottom.
# - [ ] **ML-12 done in this notebook's closing cells:** 5-minute demo outline + a social-post cut + a 3-sentence employer-facing summary.
