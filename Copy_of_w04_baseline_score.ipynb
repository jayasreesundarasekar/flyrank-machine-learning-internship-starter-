# %% [markdown]
# <a href="https://colab.research.google.com/github/jayasreesundarasekar/flyrank-machine-learning-internship-starter-/blob/main/Copy_of_w04_baseline_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-07 — Baseline Action Score and Top-20 Review
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jayasreesundarasekar/flyrank-machine-learning-internship-starter-/blob/main/work/notebooks/w04_baseline_score.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My rule and its reason codes
#
# *Write the rule in plain words first. Then the reason codes it can output.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Rule: Rank rows higher when the selected historical signals indicate a stronger opportunity for action. The score uses only information available at the decision moment. Each row receives one reason code explaining the main signal driving its score and one action label indicating the recommended action.
# Reason codes:
# HIGH_VOLUME — the row has relatively high historical volume and therefore represents a potentially valuable opportunity.
# LOW_CTR — the row has relatively weak CTR compared with its observed position, suggesting a possible CTR improvement opportunity.
# Action labels:
# REVIEW — investigate the opportunity before taking action.
# MONITOR — keep watching the signal because the evidence is weaker.

# %% [markdown]
# ## 2. Build the ranked queue (writes the CSV)
#
# *Code the score, rank everything, write work/outputs/baseline_action_score.csv.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# score = combination of historical signals only
# reason_code = ONE reason explaining the score
# action = recommended action

df["score"] = ...
df["reason_code"] = ...
df["action"] = ...

ranked = df.sort_values("score", ascending=False).reset_index(drop=True)

ranked.to_csv(
    "work/outputs/baseline_action_score.csv",
    index=False
)

ranked.head(20)

# %% [markdown]
# ## 3. Top-20 review
#
# *For each of the top 20: action, reason code, confidence note, and what would make it wrong.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# For every actual top-20 row, you need four things:
# Rank
# Action
# Reason code
# Confidence note
# What would make it wrong
# 1
# actual action
# actual reason
# Why evidence is reasonably strong
# What missing/contradictory evidence could invalidate it
# 2
# actual action
# actual reason
#...
#...
#...
#...
#...
#...
#...
# 20
# actual action
# actual reason
#...
#...
#These must be based on the actual rows produced by your notebook, so I shouldn't fabricate them.

# %% [markdown]
# ## 4. Weak picks + leakage check
#
# *Which picks look wrong and why? Confirm no product flags or future windows leaked in.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Weak picks: The weakest-looking recommendations are rows where the signals are borderline, contradictory, or based on limited volume. These should be treated as decision-support rather than automatic actions.
# Leakage check: The baseline uses only information available at the decision moment. No future-window values or label-derived features are used. Product flags are not used as inputs to the score.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
