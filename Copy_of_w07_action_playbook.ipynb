# %% [markdown]
# <a href="https://colab.research.google.com/github/jayasreesundarasekar/flyrank-machine-learning-internship-starter-/blob/main/Copy_of_w07_action_playbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-10 — Content Action Playbook
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jayasreesundarasekar/flyrank-machine-learning-internship-starter-/blob/main/work/notebooks/w07_action_playbook.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Ranked actions + reason codes
#
# *The queue: what to do first, and why, in words a human trusts.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Check that the validated ranked queue exists.
# This should come from the output of the Week-6 validated model.

print("Rows in ranked queue:", len(ranked))

# Confirm that the queue is actually ranked by score.
ranked = ranked.sort_values(
    "score",
    ascending=False
).reset_index(drop=True)

# Add ranking.
ranked["rank"] = ranked.index + 1

# Show the columns needed for human review.
display(
    ranked[
        ["rank", "score", "reason_code", "action"]
    ].head(20)
)

# Check that every row has exactly one action and one reason code.
print("Missing actions:", ranked["action"].isna().sum())
print("Missing reason codes:", ranked["reason_code"].isna().sum())

# Show the distribution of actions and reason codes.
print("\nAction counts:")
print(ranked["action"].value_counts())

print("\nReason-code counts:")
print(ranked["reason_code"].value_counts())

# %% [markdown]
# ## 2. Intended use and limits
#
# *Who uses this, for what — and where it stops being valid.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Basic checks supporting the intended-use statement.

print("Total recommendations:", len(ranked))
print("Unique actions:", ranked["action"].nunique())
print("Unique reason codes:", ranked["reason_code"].nunique())

# The queue is a decision-support output.
# It should not be treated as an automatic publishing or content-changing system.

print("\nIntended use: human-reviewed content prioritization.")
print("Output type: decision-support ranking.")
print("Automatic publishing: NOT permitted.")

# %% [markdown]
# ## 3. Human review + the no-go list
#
# *What a person must check before acting. What should never be automated.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Monitoring / retrain triggers
#
# *What would tell you the recommendations went stale?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Confirm that the queue contains the information needed for human review.

required_columns = [
    "rank",
    "score",
    "reason_code",
    "action"
]

missing_columns = [
    column for column in required_columns
    if column not in ranked.columns
]

print("Missing review columns:", missing_columns)

assert len(missing_columns) == 0, (
    "The ranked queue is missing information required for human review."
)

# No-go checks:
# Recommendations must not be treated as automatic actions.
# Human review is required before any content change.

print("\nHuman review required: YES")
print("Automatic publishing: NO")
print("Automatic deletion/redirect: NO")
print("Automatic irreversible content changes: NO")

# %% [markdown]
# ## 5. Exports for the paper
#
# *Write the queue (and any figures you want to reuse) to work/outputs/ — your paper builds on these files.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Record simple monitoring values that can be compared with future runs.

monitoring = {
    "queue_rows": len(ranked),
    "unique_actions": ranked["action"].nunique(),
    "unique_reason_codes": ranked["reason_code"].nunique(),
    "mean_score": ranked["score"].mean(),
    "median_score": ranked["score"].median(),
    "top20_mean_score": ranked.head(20)["score"].mean()
}

print("Current monitoring values:\n")

for metric, value in monitoring.items():
    print(f"{metric}: {value}")

# Future review/retraining should be considered if:
# 1. Model performance falls materially from the validated result.
# 2. Input distributions change substantially.
# 3. Important signals become unavailable or unreliable.
# 4. The recommendation mix changes unexpectedly.
# 5. Human reviewers repeatedly reject recommendations.
#
# These are investigation/revalidation triggers, not automatic retraining commands.

# Final automated checks.

checks = {
    "Queue contains rows": len(ranked) > 0,
    "Scores present": ranked["score"].notna().all(),
    "Actions present": ranked["action"].notna().all(),
    "Reason codes present": ranked["reason_code"].notna().all(),
    "Queue exported": Path(
        "work/outputs/w07_ranked_action_queue.csv"
    ).exists()
}

print("SELF-CHECK\n")

for check, passed in checks.items():
    print(("✓" if passed else "✗"), check)

assert all(checks.values()), "One or more self-checks failed."

print("\nAll automated checks passed.")

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
